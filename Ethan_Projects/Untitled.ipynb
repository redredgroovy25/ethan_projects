# %%
import pandas as pd

# %%
sum([1,2,3])
# Out:
# 6

# %%
sum(iter([1,2,3]))
# Out:
# 6

# %%
my_list = [1,2,3,4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/7h/ngbvmmw91j92fr8ybc7z6z9h0000gn/T/ipykernel_1174/4046140125.py in <module>
#       1 my_list = [1,2,3,4]
#       2
# ----> 3 print(my_list + 1)
#
# TypeError: can only concatenate list (not "int") to list
