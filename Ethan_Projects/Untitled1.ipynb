# %%
import pandas as pd
import numpy as np

# %%
name_list = ['Joe Smith','Jane Doe', 'Ignatius P Seward','Thingy McWingerson']
name_list2 = [(name, 'Paula Brown') for name in name_list]
name_list2
# Out:
# [('Joe Smith', 'Paula Brown'),
#  ('Jane Doe', 'Paula Brown'),
#  ('Ignatius P Seward', 'Paula Brown'),
#  ('Thingy McWingerson', 'Paula Brown')]

# %%
name_list_df=pd.DataFrame(name_list2)

# %%
name_list_df.rename(columns={0:'Attendee',1:'Host'})
# Out:
#              Attendee         Host
# 0           Joe Smith  Paula Brown
# 1            Jane Doe  Paula Brown
# 2   Ignatius P Seward  Paula Brown
# 3  Thingy McWingerson  Paula Brown

# %%
# Out:
# 0
