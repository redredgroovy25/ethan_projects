# %%
my_text = 7.3




if my_text.isalpha:
    print('Yay')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/7h/ngbvmmw91j92fr8ybc7z6z9h0000gn/T/ipykernel_16484/3041505720.py in <module>
#       4
#       5
# ----> 6 if my_text.isalpha:
#       7     print('Yay')
#
# AttributeError: 'float' object has no attribute 'isalpha'

# %%
my_text = 10

if isinstance(my_text, int):
    print('Yay')
# Out:
# Yay
